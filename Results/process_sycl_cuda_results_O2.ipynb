# %% [markdown]
# # This script processes SYCL and CUDA results
#
# 1. Go to SYCL-CUDA directory and compile all versions with:
# ```
# make
# ```
# 2. Run the benchmarking script
# ```
# cd scripts
# python3 run_sycl_cuda.py
# ```
# 3. The output that we will process is sycl_cuda_coffee.txt (renamed from sycl_cuda_output.out)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import sys
from statistics import mean

def tokenize(filename):
    experiment ={}

    with open(filename) as f:
        for line in f:
            tokens = line.split()
            if "Running:" in tokens:
                version=tokens[1].split("/")[2]
                input=tokens[2].split("/")[3][:-4]
                match input:
                    case "INAER_2011_Alcoy_Core":
                       cloud="Alcoy"
                    case "BABCOCK_2017_Arzua_3B":
                        cloud="Arzua"
                    case "V21_group1_densified_point_cloud":
                        cloud="BrionF"
                    case "V19_group1_densified_point_cloud":
                        cloud="BrionU"
                maxNum=int(tokens[3])
                if version not in experiment:
                    
                    experiment[version]={}
                if cloud not in experiment[version]:
                    experiment[version][cloud]={}
                experiment[version][cloud][maxNum]=[]
            if 'Construction' in tokens:
                experiment[version][cloud][maxNum].append(float(tokens[5]))
            if "Stage1" in tokens:
                experiment[version][cloud][maxNum].append(float(tokens[5]))
            if "Stage2" in tokens:
                experiment[version][cloud][maxNum].append(float(tokens[5]))
            if "Total" in tokens and "KERNEL" in tokens:
                experiment[version][cloud][maxNum].append(float(tokens[5]))
            if 'TIME' in tokens:
                experiment[version][cloud][maxNum].append(float(tokens[6]))

    return experiment

res=tokenize("sycl_cuda_coffee_O2.txt")
#print(res)

# %% [markdown]
# # Memo and NoMemo versions with best max number for each time (tree, owm, and total)

# %%
allmaxnums=[i for i in res['owm-sycl-cpu']['Alcoy']]
print(allmaxnums)

for ver in res:
    print("Version {}".format(ver))
    for cloud in res[ver]:
        treetimes=np.array([res[ver][cloud][i][0] for i in res[ver][cloud]])
        bestMNtree=np.argmin(treetimes)
        bestTreeTime=treetimes[bestMNtree]
        owmtimes=np.array([res[ver][cloud][i][3] for i in res[ver][cloud]])
        bestMNowm=np.argmin(owmtimes)
        bestowmTime=owmtimes[bestMNowm]
        totaltimes=np.array([res[ver][cloud][i][4] for i in res[ver][cloud]])
        bestMNtotal=np.argmin(totaltimes)
        besttotalTime=totaltimes[bestMNtotal]
        print("Cloud {} has TreeC. time={:.2f} (maxN={}), OWM time={:.2f} (maxN={}) and Total Time={:.2f} (maxN={}) in ms.".format(cloud,\
                                 bestTreeTime,allmaxnums[bestMNtree],bestowmTime,allmaxnums[bestMNowm],besttotalTime,allmaxnums[bestMNtotal]))
# Out:
# [4, 8, 16, 32, 64, 128, 256, 512, 1024]
# Version owm-sycl-cpu
# Cloud Alcoy has TreeC. time=376.84 (maxN=512), OWM time=199.51 (maxN=64) and Total Time=594.52 (maxN=64) in ms.
# Cloud Arzua has TreeC. time=803.10 (maxN=512), OWM time=209.73 (maxN=128) and Total Time=1034.39 (maxN=128) in ms.
# Cloud BrionF has TreeC. time=969.57 (maxN=1024), OWM time=117.64 (maxN=128) and Total Time=1092.80 (maxN=128) in ms.
# Cloud BrionU has TreeC. time=1100.99 (maxN=256), OWM time=131.60 (maxN=128) and Total Time=1240.11 (maxN=128) in ms.
# Version owm-sycl-cpu-nomemo
# Cloud Alcoy has TreeC. time=370.31 (maxN=1024), OWM time=232.99 (maxN=64) and Total Time=624.49 (maxN=64) in ms.
# Cloud Arzua has TreeC. time=802.44 (maxN=512), OWM time=295.38 (maxN=128) and Total Time=1111.43 (maxN=128) in ms.
# Cloud BrionF has TreeC. time=961.28 (maxN=256), OWM time=209.70 (maxN=128) and Total Time=1181.87 (maxN=128) in ms.
# Cloud BrionU has TreeC. time=1099.07 (maxN=1024), OWM time=246.58 (maxN=128) and Total Time=1359.27 (maxN=128) in ms.
# Version owm-sycl-igpu
# Cloud Alcoy has TreeC. time=2913.15 (maxN=256), OWM time=1033.55 (maxN=8) and Total Time=4106.32 (maxN=8) in ms.
# Cloud Arzua has TreeC. time=2494.13 (maxN=512), OWM time=1126.65 (maxN=16) and Total Time=3775.44 (maxN=16) in ms.
# Cloud BrionF has TreeC. time=7229.31 (maxN=512), OWM time=639.78 (maxN=8) and Total Time=8028.60 (maxN=16) in ms.
# Cloud BrionU has TreeC. time=3218.06 (maxN=512), OWM time=687.67 (maxN=8) and Total Time=4087.40 (maxN=16) in ms.
# Version owm-sycl-igpu-nomemo
# Cloud Alcoy has TreeC. time=2912.75 (maxN=256), OWM time=1398.19 (maxN=64) and Total Time=4323.84 (maxN=64) in ms.
# Cloud Arzua has TreeC. time=2493.86 (maxN=512), OWM time=2405.40 (maxN=32) and Total Time=4925.48 (maxN=128) in ms.
# Cloud BrionF has TreeC. time=7227.53 (maxN=512), OWM time=1974.28 (maxN=64) and Total Time=9222.79 (maxN=64) in ms.
# Cloud BrionU has TreeC. time=3218.94 (maxN=512), OWM time=2249.64 (maxN=64) and Total Time=5519.95 (maxN=128) in ms.
# Version owm-sycl-dgpu
# Cloud Alcoy has TreeC. time=172.21 (maxN=512), OWM time=202.77 (maxN=8) and Total Time=414.54 (maxN=64) in ms.
# Cloud Arzua has TreeC. time=201.82 (maxN=256), OWM time=233.57 (maxN=16) and Total Time=529.30 (maxN=16) in ms.
# Cloud BrionF has TreeC. time=592.67 (maxN=512), OWM time=137.42 (maxN=16) and Total Time=784.43 (maxN=64) in ms.
# Cloud BrionU has TreeC. time=413.07 (maxN=512), OWM time=154.57 (maxN=16) and Total Time=639.84 (maxN=32) in ms.
# Version owm-sycl-dgpu-nomemo
# Cloud Alcoy has TreeC. time=171.53 (maxN=512), OWM time=265.90 (maxN=64) and Total Time=450.43 (maxN=64) in ms.
# Cloud Arzua has TreeC. time=201.73 (maxN=256), OWM time=471.53 (maxN=128) and Total Time=679.63 (maxN=128) in ms.
# Cloud BrionF has TreeC. time=592.07 (maxN=512), OWM time=440.40 (maxN=128) and Total Time=1046.80 (maxN=128) in ms.
# Cloud BrionU has TreeC. time=413.07 (maxN=512), OWM time=500.17 (maxN=128) and Total Time=930.01 (maxN=128) in ms.
# Version owm-cuda
# Cloud Alcoy has TreeC. time=20.63 (maxN=256), OWM time=111.56 (maxN=16) and Total Time=231.41 (maxN=64) in ms.
# Cloud Arzua has TreeC. time=40.07 (maxN=128), OWM time=144.34 (maxN=32) and Total Time=370.09 (maxN=32) in ms.
# Cloud BrionF has TreeC. time=59.56 (maxN=256), OWM time=88.53 (maxN=32) and Total Time=404.79 (maxN=64) in ms.
# Cloud BrionU has TreeC. time=68.18 (maxN=512), OWM time=96.69 (maxN=32) and Total Time=460.55 (maxN=64) in ms.
# Version owm-cuda-nomemo
# Cloud Alcoy has TreeC. time=20.57 (maxN=256), OWM time=134.80 (maxN=32) and Total Time=247.66 (maxN=64) in ms.
# Cloud Arzua has TreeC. time=40.12 (maxN=512), OWM time=228.58 (maxN=64) and Total Time=433.47 (maxN=64) in ms.
# Cloud BrionF has TreeC. time=59.51 (maxN=512), OWM time=236.64 (maxN=256) and Total Time=536.02 (maxN=256) in ms.
# Cloud BrionU has TreeC. time=67.90 (maxN=256), OWM time=253.86 (maxN=256) and Total Time=593.38 (maxN=256) in ms.

# %% [markdown]
# # Execution time of memo versions for all maxNumbers

# %%
def plot_alltimes(results,version):
    #Configuration variables
    titlefs = 20
    ylabelfs = 18
    xlabelfs = 18
    xticksfs = 16
    yticksfs = 16
    legendfs = 14
    linew = 2
    markers = 8
    marks=['o-','x-','s-','v-','+-']

    #fig = plt.figure()
    labels=['OWM','Tree Const.','OWM+Tree C.']
    x=list(results[version]['Alcoy'].keys())
    xticks=range(1,len(x)+1)
    #define grid of plots
    fig, axs = plt.subplots(nrows=1, ncols=4,figsize=(15, 5), constrained_layout=True) #sharey=True
    for i,name in zip(range(4),['Alcoy','Arzua','BrionF','BrionU']):
        axs[i].plot(np.array(xticks), np.array([results[version][name][i][3] for i in x]), marks[0], linewidth=linew, markersize=markers)
        axs[i].plot(np.array(xticks), np.array([results[version][name][i][0] for i in x]), marks[1], linewidth=linew, markersize=markers)
        axs[i].plot(np.array(xticks), np.array([results[version][name][i][4] for i in x]), marks[2], linewidth=linew, markersize=markers)

        axs[i].set_title(name,fontsize=16)
        axs[i].set_xlabel('MaxNumber', fontsize=xlabelfs)
        axs[i].set_xticks(ticks=xticks[::3], labels=x[::3],fontsize=xticksfs)
        # axs[i].yticks(fontsize=yticksfs)
        axs[i].grid()

    fig.suptitle(version + ' sequential time (millisec.)',  fontweight='bold', fontsize=18)
    axs[0].set_ylabel('Time (millisec.)', fontsize=ylabelfs)
    axs[0].legend(labels,loc='best', fontsize= 14)
    #axs[i].show()

plot_alltimes(res,"owm-sycl-cpu")
plot_alltimes(res,"owm-sycl-igpu")
plot_alltimes(res,"owm-sycl-dgpu")
plot_alltimes(res,"owm-cuda")

# %% [markdown]
# # Compare CPU-optim 4 with all nomemo versions and MaxNumber=512

# %%
import pandas as pd
df=pd.read_csv('All_Optimizations.csv',sep=';')
df=df.drop(df.index[4:28])
df.reset_index(drop=True, inplace=True)
df.insert(4,"Total",0)
df['Total']=df['TimeTree']+df['TimeOWM']
print(df)
base=df.loc[4:7,'TimeTree':'Total']
basea=np.array(base)*1000 #in ms
print(basea)
# Out:
#   Optimization   Cloud  TimeTree   TimeOWM      Total  Level  MinRadMaxNum
# 0     Baseline   Alcoy  4.737780  3.733700   8.471480      0           0.0
# 1     Baseline   Arzua  5.749600  4.105800   9.855400      0           0.0
# 2     Baseline  BrionF  5.971560  6.233900  12.205460      0           0.0
# 3     Baseline  BrionU  6.761090  7.327300  14.088390      0           0.0
# 4  Opt4-MinRad   Alcoy  0.167986  0.275714   0.443700      5           1.8
# 5  Opt4-MinRad   Arzua  0.329102  0.270224   0.599326      5           0.5
# 6  Opt4-MinRad  BrionF  0.766410  0.276490   1.042900      4           0.1
# 7  Opt4-MinRad  BrionU  0.866690  0.336850   1.203540      4           0.1
# [[ 167.986  275.714  443.7  ]
#  [ 329.102  270.224  599.326]
#  [ 766.41   276.49  1042.9  ]
#  [ 866.69   336.85  1203.54 ]]

# %%
mN=512
for ver in res:
    if "nomemo" not in ver.split("-"):
        continue
    print("Version {}".format(ver))
    for cloud, i in zip(res[ver],range(4)):
        treetime=res[ver][cloud][mN][0]
        treesp=basea[i,0]/treetime
        owmtime=res[ver][cloud][mN][3]
        owmsp=basea[i,1]/owmtime
        totaltime=res[ver][cloud][mN][4]
        totalsp=basea[i,2]/totaltime
        print("Cloud {} with maxN={} has TreeC. time={:.2f} ({:.2f}x), OWM time={:.2f} ({:.2f}x) and Total Time={:.2f} ({:.2f}x) in ms.".format(cloud, mN,\
                                    treetime, treesp, owmtime, owmsp, totaltime, totalsp))
# Out:
# Version owm-sycl-cpu-nomemo
# Cloud Alcoy with maxN=512 has TreeC. time=377.24 (0.45x), OWM time=299.60 (0.92x) and Total Time=676.84 (0.66x) in ms.
# Cloud Arzua with maxN=512 has TreeC. time=802.44 (0.41x), OWM time=388.21 (0.70x) and Total Time=1190.65 (0.50x) in ms.
# Cloud BrionF with maxN=512 has TreeC. time=973.72 (0.79x), OWM time=231.60 (1.19x) and Total Time=1205.32 (0.87x) in ms.
# Cloud BrionU with maxN=512 has TreeC. time=1100.01 (0.79x), OWM time=262.87 (1.28x) and Total Time=1362.88 (0.88x) in ms.
# Version owm-sycl-igpu-nomemo
# Cloud Alcoy with maxN=512 has TreeC. time=2915.82 (0.06x), OWM time=2118.08 (0.13x) and Total Time=5033.89 (0.09x) in ms.
# Cloud Arzua with maxN=512 has TreeC. time=2493.86 (0.13x), OWM time=3864.68 (0.07x) and Total Time=6358.54 (0.09x) in ms.
# Cloud BrionF with maxN=512 has TreeC. time=7227.53 (0.11x), OWM time=2590.74 (0.11x) and Total Time=9818.27 (0.11x) in ms.
# Cloud BrionU with maxN=512 has TreeC. time=3218.94 (0.27x), OWM time=2732.09 (0.12x) and Total Time=5951.03 (0.20x) in ms.
# Version owm-sycl-dgpu-nomemo
# Cloud Alcoy with maxN=512 has TreeC. time=171.53 (0.98x), OWM time=523.65 (0.53x) and Total Time=695.18 (0.64x) in ms.
# Cloud Arzua with maxN=512 has TreeC. time=206.19 (1.60x), OWM time=849.30 (0.32x) and Total Time=1055.49 (0.57x) in ms.
# Cloud BrionF with maxN=512 has TreeC. time=592.07 (1.29x), OWM time=489.15 (0.57x) and Total Time=1081.22 (0.96x) in ms.
# Cloud BrionU with maxN=512 has TreeC. time=413.07 (2.10x), OWM time=555.71 (0.61x) and Total Time=968.78 (1.24x) in ms.
# Version owm-cuda-nomemo
# Cloud Alcoy with maxN=512 has TreeC. time=20.83 (8.07x), OWM time=280.04 (0.98x) and Total Time=384.17 (1.15x) in ms.
# Cloud Arzua with maxN=512 has TreeC. time=40.12 (8.20x), OWM time=424.71 (0.64x) and Total Time=625.30 (0.96x) in ms.
# Cloud BrionF with maxN=512 has TreeC. time=59.51 (12.88x), OWM time=247.08 (1.12x) and Total Time=544.62 (1.91x) in ms.
# Cloud BrionU with maxN=512 has TreeC. time=69.67 (12.44x), OWM time=271.84 (1.24x) and Total Time=620.17 (1.94x) in ms.

# %%
df=pd.read_csv('All_Optimizations.csv',sep=';')
df=df.drop(df.index[4:28])
df.reset_index(drop=True, inplace=True)
df.insert(4,"Total",0)
df['Total']=df['TimeTree']+df['TimeOWM']
print(df)
base=df.loc[4:7,'TimeTree':'TimeOWM']
basea=np.array(base)*1000 #in ms
print(basea)
mN=512
for ver in res:
    if "nomemo" not in ver.split("-"):
        continue
    #print("Version {}".format(ver))
    times=np.array([[res[ver][cloud][mN][0],res[ver][cloud][mN][3]] for cloud in res[ver]])
    #for cloud in res[ver]:
        #print("Cloud {} with maxN={} has TreeC. time={:.2f}, OWM time={:.2f} in ms.".format(cloud,\
        #                     mN,res[ver][cloud][mN][0],res[ver][cloud][mN][3]))
    basea=np.hstack((basea,times))
print(basea)
# Out:
#   Optimization   Cloud  TimeTree   TimeOWM      Total  Level  MinRadMaxNum
# 0     Baseline   Alcoy  4.737780  3.733700   8.471480      0           0.0
# 1     Baseline   Arzua  5.749600  4.105800   9.855400      0           0.0
# 2     Baseline  BrionF  5.971560  6.233900  12.205460      0           0.0
# 3     Baseline  BrionU  6.761090  7.327300  14.088390      0           0.0
# 4  Opt4-MinRad   Alcoy  0.167986  0.275714   0.443700      5           1.8
# 5  Opt4-MinRad   Arzua  0.329102  0.270224   0.599326      5           0.5
# 6  Opt4-MinRad  BrionF  0.766410  0.276490   1.042900      4           0.1
# 7  Opt4-MinRad  BrionU  0.866690  0.336850   1.203540      4           0.1
# [[167.986 275.714]
#  [329.102 270.224]
#  [766.41  276.49 ]
#  [866.69  336.85 ]]
# [[ 167.986   275.714   377.242   299.595  2915.82   2118.08    171.531
#    523.649    20.8273  280.035 ]
#  [ 329.102   270.224   802.436   388.211  2493.86   3864.68    206.192
#    849.297    40.1176  424.71  ]
#  [ 766.41    276.49    973.72    231.601  7227.53   2590.74    592.073
#    489.146    59.5069  247.08  ]
#  [ 866.69    336.85   1100.01    262.868  3218.94   2732.09    413.072
#    555.71     69.6655  271.839 ]]

# %%
def plot_nomemo(npa):
    #Configuration variables
    titlefs = 20
    ylabelfs = 18
    xlabelfs = 18
    xticksfs = 16
    yticksfs = 16
    legendfs = 14
    linew = 2
    markers = 8
    marks=['o-','x-','s-','v-','+-']


    #fig = plt.figure()
    phases=['OWM Trav.','Tree Const.']
    clouds=['Alcoy','Arzua','BrionF','BrionU']
    versions=['TBB base','S-CPU','S-iGPU','S-dGPU','CUDA']
    x=np.arange(1,len(versions)+1)
    width=0.35
    #define grid of plots
    fig, axs = plt.subplots(nrows=1, ncols=4,figsize=(15, 5), constrained_layout=True)#, sharey=True)
    for i,name in zip(range(len(clouds)),clouds):
        b=np.zeros(len(versions))
        for j,z in zip(phases,reversed(range(len(phases)))): #reversed to have OWM first
            axs[i].bar(x, npa[i][z::2], width, label=j, bottom=b)
            b=b+npa[i][z::2]

        axs[i].set_title(name,fontsize=16)
        axs[i].set_xlabel('Version', fontsize=xlabelfs)
        axs[i].set_xticks(x,labels=versions,fontsize=xticksfs,rotation = 45)
        # axs[i].yticks(fontsize=yticksfs)
        axs[i].grid()
    fig.suptitle('Execution time (ms.) of each version',  fontweight='bold', fontsize=18)
    
    axs[0].set_ylabel('Time in milliseconds', fontsize=ylabelfs)
    axs[0].legend(phases,loc='best', fontsize= 14)
    pp = PdfPages("Time-nomemo-maxnum512.pdf")
    pp.savefig(fig)
    pp.close()

plot_nomemo(basea)

# %% [markdown]
# # Memo vs NoMemo for MaxNumber=512

# %%
#memo vs no memo comparison
mN=512
for ver in res:
    if "nomemo" in ver.split("-"):
        continue
    print("Version {}".format(ver))
    for cloud in res[ver]:
        owmtimeNoMemo=res[ver+"-nomemo"][cloud][mN][3]
        owmtimeMemo=res[ver][cloud][mN][3]
        print("Cloud {} with maxN={} has OWM time={:.2f} ms  that is {:.2f}x faster than without memo (time={:.2f} ms)".format(cloud,mN, owmtimeMemo,\
                                                       owmtimeNoMemo/owmtimeMemo, owmtimeNoMemo ))
# Out:
# Version owm-sycl-cpu
# Cloud Alcoy with maxN=512 has OWM time=284.48 ms  that is 1.05x faster than without memo (time=299.60 ms)
# Cloud Arzua with maxN=512 has OWM time=331.52 ms  that is 1.17x faster than without memo (time=388.21 ms)
# Cloud BrionF with maxN=512 has OWM time=173.13 ms  that is 1.34x faster than without memo (time=231.60 ms)
# Cloud BrionU with maxN=512 has OWM time=190.37 ms  that is 1.38x faster than without memo (time=262.87 ms)
# Version owm-sycl-igpu
# Cloud Alcoy with maxN=512 has OWM time=2112.89 ms  that is 1.00x faster than without memo (time=2118.08 ms)
# Cloud Arzua with maxN=512 has OWM time=3632.20 ms  that is 1.06x faster than without memo (time=3864.68 ms)
# Cloud BrionF with maxN=512 has OWM time=2154.91 ms  that is 1.20x faster than without memo (time=2590.74 ms)
# Cloud BrionU with maxN=512 has OWM time=2230.98 ms  that is 1.22x faster than without memo (time=2732.09 ms)
# Version owm-sycl-dgpu
# Cloud Alcoy with maxN=512 has OWM time=523.36 ms  that is 1.00x faster than without memo (time=523.65 ms)
# Cloud Arzua with maxN=512 has OWM time=807.36 ms  that is 1.05x faster than without memo (time=849.30 ms)
# Cloud BrionF with maxN=512 has OWM time=409.33 ms  that is 1.19x faster than without memo (time=489.15 ms)
# Cloud BrionU with maxN=512 has OWM time=457.99 ms  that is 1.21x faster than without memo (time=555.71 ms)
# Version owm-cuda
# Cloud Alcoy with maxN=512 has OWM time=282.02 ms  that is 0.99x faster than without memo (time=280.04 ms)
# Cloud Arzua with maxN=512 has OWM time=408.64 ms  that is 1.04x faster than without memo (time=424.71 ms)
# Cloud BrionF with maxN=512 has OWM time=223.27 ms  that is 1.11x faster than without memo (time=247.08 ms)
# Cloud BrionU with maxN=512 has OWM time=236.37 ms  that is 1.15x faster than without memo (time=271.84 ms)

# %%
print("\\begin{tabular}{|c|ccc|ccc|ccc|}\hline")
print(" & \multicolumn{3}{c|}{S-CPU}  & \multicolumn{3}{c|}{S-dGPU} & \multicolumn{3}{c|}{CUDA} \\\\ ")  
print(" Cloud &  NM &  M & IMP &  NM &  M & IMP &  NM &  M & IMP \\\\ \hline")
mN=512
versions=res.keys()
clouds=res['owm-sycl-cpu'].keys()
for i in clouds:
    print(i,end='')
    for j in versions:
        if "nomemo" in j.split("-") or "igpu" in j.split("-"):
            continue
        print("& {:0.2f} & {:0.2f} & {:0.2f}x ".format(res[j+"-nomemo"][i][mN][3],res[j][i][mN][3],res[j+"-nomemo"][i][mN][3]/res[j][i][mN][3]),end='')
    print("\\\\ \hline")
print("\\end{tabular}")
# Out:
# \begin{tabular}{|c|ccc|ccc|ccc|}\hline
#  & \multicolumn{3}{c|}{S-CPU}  & \multicolumn{3}{c|}{S-dGPU} & \multicolumn{3}{c|}{CUDA} \\
#  Cloud &  NM &  M & IMP &  NM &  M & IMP &  NM &  M & IMP \\ \hline
# Alcoy& 299.60 & 284.48 & 1.05x & 523.65 & 523.36 & 1.00x & 280.04 & 282.02 & 0.99x \\ \hline
# Arzua& 388.21 & 331.52 & 1.17x & 849.30 & 807.36 & 1.05x & 424.71 & 408.64 & 1.04x \\ \hline
# BrionF& 231.60 & 173.13 & 1.34x & 489.15 & 409.33 & 1.19x & 247.08 & 223.27 & 1.11x \\ \hline
# BrionU& 262.87 & 190.37 & 1.38x & 555.71 & 457.99 & 1.21x & 271.84 & 236.37 & 1.15x \\ \hline
# \end{tabular}

# %% [markdown]
# # Improvement factor when searching for the best maxNumber

# %%
mN=512
for ver in res:
    if "nomemo" in ver.split("-"):
        continue
    print("Version {}".format(ver))
    for cloud in res[ver]:
        bestMNtotal=min(res[ver][cloud], key=lambda x: res[ver][cloud][x][4])
        bestTreeTime=res[ver][cloud][bestMNtotal][0]
        bestowmTime=res[ver][cloud][bestMNtotal][3]
        besttotalTime=res[ver][cloud][bestMNtotal][4]
        treetime=res[ver][cloud][mN][0]
        owmtime=res[ver][cloud][mN][3]
        totaltime=res[ver][cloud][mN][4]
        print("Cloud {} with MaxNum={} has TreeC. time={:.2f} ({:.2f}x), OWM time={:.2f} ({:.2f}x) and Total Time={:.2f} ({:.2f}x) in ms.".format(cloud,bestMNtotal,\
                                 bestTreeTime,treetime/bestTreeTime,bestowmTime,owmtime/bestowmTime,besttotalTime,totaltime/besttotalTime))
# Out:
# Version owm-sycl-cpu
# Cloud Alcoy with MaxNum=64 has TreeC. time=395.00 (0.95x), OWM time=199.51 (1.43x) and Total Time=594.52 (1.11x) in ms.
# Cloud Arzua with MaxNum=128 has TreeC. time=824.66 (0.97x), OWM time=209.73 (1.58x) and Total Time=1034.39 (1.10x) in ms.
# Cloud BrionF with MaxNum=128 has TreeC. time=975.16 (1.00x), OWM time=117.64 (1.47x) and Total Time=1092.80 (1.05x) in ms.
# Cloud BrionU with MaxNum=128 has TreeC. time=1108.51 (1.00x), OWM time=131.60 (1.45x) and Total Time=1240.11 (1.04x) in ms.
# Version owm-sycl-igpu
# Cloud Alcoy with MaxNum=8 has TreeC. time=3072.78 (0.95x), OWM time=1033.55 (2.04x) and Total Time=4106.32 (1.23x) in ms.
# Cloud Arzua with MaxNum=16 has TreeC. time=2648.79 (0.94x), OWM time=1126.65 (3.22x) and Total Time=3775.44 (1.62x) in ms.
# Cloud BrionF with MaxNum=16 has TreeC. time=7380.73 (0.98x), OWM time=647.87 (3.33x) and Total Time=8028.60 (1.17x) in ms.
# Cloud BrionU with MaxNum=16 has TreeC. time=3385.11 (0.95x), OWM time=702.29 (3.18x) and Total Time=4087.40 (1.33x) in ms.
# Version owm-sycl-dgpu
# Cloud Alcoy with MaxNum=64 has TreeC. time=184.48 (0.93x), OWM time=230.06 (2.27x) and Total Time=414.54 (1.68x) in ms.
# Cloud Arzua with MaxNum=16 has TreeC. time=295.74 (0.70x), OWM time=233.57 (3.46x) and Total Time=529.30 (1.92x) in ms.
# Cloud BrionF with MaxNum=64 has TreeC. time=621.98 (0.95x), OWM time=162.45 (2.52x) and Total Time=784.43 (1.28x) in ms.
# Cloud BrionU with MaxNum=32 has TreeC. time=474.05 (0.87x), OWM time=165.78 (2.76x) and Total Time=639.84 (1.36x) in ms.
# Version owm-cuda
# Cloud Alcoy with MaxNum=64 has TreeC. time=21.38 (0.98x), OWM time=124.50 (2.27x) and Total Time=231.41 (1.67x) in ms.
# Cloud Arzua with MaxNum=32 has TreeC. time=45.15 (0.89x), OWM time=144.34 (2.83x) and Total Time=370.09 (1.65x) in ms.
# Cloud BrionF with MaxNum=64 has TreeC. time=61.39 (0.98x), OWM time=97.84 (2.28x) and Total Time=404.79 (1.30x) in ms.
# Cloud BrionU with MaxNum=64 has TreeC. time=70.87 (0.96x), OWM time=106.21 (2.23x) and Total Time=460.55 (1.25x) in ms.

# %%
print("\\begin{tabular}{|c|cccc|cccc|cccc|}\hline")
print(" & \multicolumn{4}{c|}{S-CPU} &  \multicolumn{4}{c|}{S-dGPU} & \multicolumn{4}{c|}{CUDA} \\\\ ")  
print(" Cloud &  MaxNum & Tree &  OWM & Tot &  MaxNum & Tree &  OWM & Tot &  MaxNum & Tree &  OWM & Tot  \\\\ \hline")
mN=512
versions=res.keys()
clouds=res['owm-sycl-cpu'].keys()
for cloud in clouds:
    print(cloud,end='')
    for ver in versions:
        if "nomemo" in ver.split("-") or "igpu" in ver.split("-"):
            continue
        bestMNtotal=min(res[ver][cloud], key=lambda x: res[ver][cloud][x][4])
        bestTreeTime=res[ver][cloud][bestMNtotal][0]
        bestowmTime=res[ver][cloud][bestMNtotal][3]
        besttotalTime=res[ver][cloud][bestMNtotal][4]
        treetime=res[ver][cloud][mN][0]
        owmtime=res[ver][cloud][mN][3]
        totaltime=res[ver][cloud][mN][4]
        print("& {} & {:0.2f}x & {:0.2f}x & {:0.2f}x ".format(bestMNtotal,treetime/bestTreeTime,owmtime/bestowmTime,totaltime/besttotalTime),end='')
    print("\\\\ \hline")
print("\\end{tabular}")
# Out:
# \begin{tabular}{|c|cccc|cccc|cccc|}\hline
#  & \multicolumn{4}{c|}{S-CPU} &  \multicolumn{4}{c|}{S-dGPU} & \multicolumn{4}{c|}{CUDA} \\
#  Cloud &  MaxNum & Tree &  OWM & Tot &  MaxNum & Tree &  OWM & Tot &  MaxNum & Tree &  OWM & Tot  \\ \hline
# Alcoy& 64 & 0.95x & 1.43x & 1.11x & 64 & 0.93x & 2.27x & 1.68x & 64 & 0.98x & 2.27x & 1.67x \\ \hline
# Arzua& 128 & 0.97x & 1.58x & 1.10x & 16 & 0.70x & 3.46x & 1.92x & 32 & 0.89x & 2.83x & 1.65x \\ \hline
# BrionF& 128 & 1.00x & 1.47x & 1.05x & 64 & 0.95x & 2.52x & 1.28x & 64 & 0.98x & 2.28x & 1.30x \\ \hline
# BrionU& 128 & 1.00x & 1.45x & 1.04x & 32 & 0.87x & 2.76x & 1.36x & 64 & 0.96x & 2.23x & 1.25x \\ \hline
# \end{tabular}

# %% [markdown]
# # Save results in All_Optimizations.csv

# %%
output="All_OptimizationsSYCL-CUDA_O2.csv"

f = open(output, "a")

for ver in res:
    #print("Version {}".format(ver))
    for cloud in res[ver]:
        totaltimes=np.array([res[ver][cloud][i][4] for i in res[ver][cloud]])
        bestMNtotal=min(res[ver][cloud], key=lambda x: res[ver][cloud][x][4])
        bestTreeTime=res[ver][cloud][bestMNtotal][0]
        bestowmTime=res[ver][cloud][bestMNtotal][3]
        print("{};{};{:.5f};{:.5f};{};{}".format(ver,cloud,bestTreeTime/1000,bestowmTime/1000,0,bestMNtotal))
        f.write("{};{};{:.5f};{:.5f};{};{}\n".format(ver,cloud,bestTreeTime/1000,bestowmTime/1000,0,bestMNtotal))
f.close()
# Out:
# owm-sycl-cpu;Alcoy;0.39500;0.19951;0;64
# owm-sycl-cpu;Arzua;0.82466;0.20973;0;128
# owm-sycl-cpu;BrionF;0.97516;0.11764;0;128
# owm-sycl-cpu;BrionU;1.10851;0.13160;0;128
# owm-sycl-cpu-nomemo;Alcoy;0.39150;0.23299;0;64
# owm-sycl-cpu-nomemo;Arzua;0.81605;0.29538;0;128
# owm-sycl-cpu-nomemo;BrionF;0.97217;0.20970;0;128
# owm-sycl-cpu-nomemo;BrionU;1.11269;0.24658;0;128
# owm-sycl-igpu;Alcoy;3.07278;1.03355;0;8
# owm-sycl-igpu;Arzua;2.64879;1.12665;0;16
# owm-sycl-igpu;BrionF;7.38073;0.64787;0;16
# owm-sycl-igpu;BrionU;3.38511;0.70229;0;16
# owm-sycl-igpu-nomemo;Alcoy;2.92565;1.39819;0;64
# owm-sycl-igpu-nomemo;Arzua;2.51362;2.41186;0;128
# owm-sycl-igpu-nomemo;BrionF;7.24851;1.97428;0;64
# owm-sycl-igpu-nomemo;BrionU;3.23104;2.28891;0;128
# owm-sycl-dgpu;Alcoy;0.18448;0.23006;0;64
# owm-sycl-dgpu;Arzua;0.29574;0.23357;0;16
# owm-sycl-dgpu;BrionF;0.62198;0.16245;0;64
# owm-sycl-dgpu;BrionU;0.47405;0.16578;0;32
# owm-sycl-dgpu-nomemo;Alcoy;0.18452;0.26590;0;64
# owm-sycl-dgpu-nomemo;Arzua;0.20809;0.47153;0;128
# owm-sycl-dgpu-nomemo;BrionF;0.60640;0.44040;0;128
# owm-sycl-dgpu-nomemo;BrionU;0.42984;0.50017;0;128
# owm-cuda;Alcoy;0.02138;0.12450;0;64
# owm-cuda;Arzua;0.04515;0.14434;0;32
# owm-cuda;BrionF;0.06139;0.09784;0;64
# owm-cuda;BrionU;0.07087;0.10621;0;64
# owm-cuda-nomemo;Alcoy;0.02140;0.14065;0;64
# owm-cuda-nomemo;Arzua;0.04098;0.22858;0;64
# owm-cuda-nomemo;BrionF;0.05988;0.23664;0;256
# owm-cuda-nomemo;BrionU;0.06790;0.25386;0;256
